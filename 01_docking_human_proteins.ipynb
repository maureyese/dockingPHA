# %% [markdown]
# # **Activity 2: Molecular docking of immune and skin proteins**
#
# Before you proceed this workflow, I encourage you to follow the tutorials on ```00_tutorials/``` folder prior programming to have everything downloaded.
#
# In this workflow, we will be docking our ligand with multiple human proteins.

# %% [markdown]
# Make sure you already have installed ```requests```, ```biopython```, ```openbabel```, ```MDAnalysis```, ```numpy```, ```pandas``` libraries. Otherwise, copy the following lines and paste it on the terminal:
#
# 1. ```conda activate vina```
# 2. ```sudo apt install openbabel```
# 3. ```conda install requests biopython openbabel MDAnalysis numpy pandas```

# %% [markdown]
# ## 1. Create PDBQT file for Ligand
#
# Get the SDF file of ligand from PubChem: https://pubchem.ncbi.nlm.nih.gov/

# %%
# Custom Library to prepare Ligand using Openbabel
from docking_functions.PrepareLigand import prepare_ligand
# Library for file handling and export
import os

ligands_pdbqt = {} # Dictionary to store PDBQT files from n-unit oligomers

# Set Directory with PHB files
input_dir = "files/"
# Set Output Directory for Ligands
ligand_dir = os.path.join("output", "ligand_files")
os.makedirs(ligand_dir, exist_ok=True)

for num_units in range(1, 13):  # 1 to 6 units; Modify this range as needed
    try:
        # Convert PDB file to PDBQT
        ligand_pdbqt = prepare_ligand(
            input_file = os.path.join(input_dir, f"phb_{num_units}_unit.pdb"),
            output_dir = ligand_dir,
            ph = 7.4,
            charge_method = 'gasteiger'
        )
        # Store PDBQT filename
        ligands_pdbqt[num_units] = ligands_pdbqt
    except Exception as e:
        print(e)

print("\nPDBQT conversion completed.")
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_1_unit.pdbqt
# Ligand prepared successfully: output/ligand_files/phb_2_unit.pdbqt
# Ligand prepared successfully: output/ligand_files/phb_3_unit.pdbqt
# 1 molecule converted
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_4_unit.pdbqt
# Ligand prepared successfully: output/ligand_files/phb_5_unit.pdbqt
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_6_unit.pdbqt
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_7_unit.pdbqt
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_8_unit.pdbqt
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_9_unit.pdbqt
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_10_unit.pdbqt
# 1 molecule converted
# Ligand prepared successfully: output/ligand_files/phb_11_unit.pdbqt
# Ligand prepared successfully: output/ligand_files/phb_12_unit.pdbqt
#
# PDBQT conversion completed.
# 1 molecule converted

# %% [markdown]
# ## 2. Create PDBQT file from Protein
#
# We will download PDB file directly from PDB through request

# %%
# Custom Library to download PDB files from PDB using Requests
from docking_functions.DownloadPDB import download_pdb_file

pdb_ids = [
    ("6EC0", "Keratin 1", True), # PDB ID, PDB Protein Name, deduplicate
    ("7CWK", "Collagen type I", True),
    ("4BSO", "R-SPONDIN-1", True),
    ("1RG8", "Heparin-binding growth factor 1", True),
    ("1CSG", "Granulocyte-macrophage colony-stimulating factor", True),
    ("1TGJ", "TRANSFORMING GROWTH FACTOR-BETA 3", True),
    ("1VPF", "VASCULAR ENDOTHELIAL GROWTH FACTOR", True),
    ("2Z80", "Toll-like receptor 2, Variable lymphocyte receptor B", True),
    # Add as needed
]

# Set Output Directory for Receptors
receptor_dir = os.path.join("output", "receptor_files")
os.makedirs(receptor_dir, exist_ok=True)

pdb_filenames = [] # List to store downloaded PDB filenames

for pdb_id, pdb_name, deduplicate in pdb_ids:
    # Download PDB file
    pdb_filename = download_pdb_file(
        pdb_id=pdb_id, # ID from PDB
        output_dir=receptor_dir # Folder to store PDB
    )
    # Append PDB filename to list
    pdb_filenames.append((pdb_filename,pdb_name,deduplicate))
# Out:
#   Downloaded PDB file: output/receptor_files/6EC0.pdb
#   Downloaded PDB file: output/receptor_files/7CWK.pdb
#   Downloaded PDB file: output/receptor_files/4BSO.pdb
#   Downloaded PDB file: output/receptor_files/1RG8.pdb
#   Downloaded PDB file: output/receptor_files/1CSG.pdb
#   Downloaded PDB file: output/receptor_files/1TGJ.pdb
#   Downloaded PDB file: output/receptor_files/1VPF.pdb
#   Downloaded PDB file: output/receptor_files/2Z80.pdb

# %% [markdown]
# Convert PDB file from Protein to PDBQT

# %%
# Custom Library to prepare Receptor using Openbabel
from docking_functions.PrepareReceptor import clean_and_convert_pdb_to_pdbqt

pdbqt_filenames = [] # List to store converted PDBQT filenames

# Iterate over each filename downloaded
for pdb_filename, pdb_name, deduplicate in pdb_filenames:
    # 1. Remove non-aminoacidic elements from PDB
    # 2. Conserve chains from Protein
    # 3. Remove structure duplicates
    # 4. pH = 7.4
    # 5. Charge residues using 'Gasteiger'
    cleaned_pdb, output_pdbqt = clean_and_convert_pdb_to_pdbqt(
        pdb_filename, 
        protein_name=pdb_name,
        deduplicate=deduplicate,
        similarity_threshold=80.0,
        ph=7.4,
        charge_method='gasteiger',
        remove_polar_hydrogens=True
    )
    # Append PDBQT filename to list
    pdbqt_filenames.append(output_pdbqt)
# Out:
# Found protein 'KERATIN 1' with chains: ['A']
# Final chains to keep: ['A']
# /home/mreyes/miniconda3/envs/dockingpha/lib/python3.12/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# Removed UNK/UNL residues from output/receptor_files/6EC0_Keratin_1_cleaned.pdb
# Conversion successful: output/receptor_files/6EC0_Keratin_1_cleaned.pdb -> output/receptor_files/6EC0_Keratin_1.pdbqt
# Found protein 'COLLAGEN TYPE I' with chains: ['A', 'B', 'C']
#
# Deduplicating chains with 80.0% similarity threshold...
# Chain A: Length=21, Unknown residues=0
# Chain B: Length=21, Unknown residues=0
# Chain C: Length=20, Unknown residues=0
#
# Comparing Chain A vs Chain B:
# 	- Similarity: 100.0%
# 	- Chains are 100.0% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain B: 0 unknown residues
# 	- Discarding Chain B (redundant)
#
# Comparing Chain A vs Chain C:
# 	- Similarity: 95.2%
# 	- Chains are 95.2% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain C: 0 unknown residues
# 	- Discarding Chain C (redundant)
#
# ============================================================
# Chains to keep: ['A']
# ============================================================
#
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/7CWK_Collagen_type_I_cleaned.pdb
# Conversion successful: output/receptor_files/7CWK_Collagen_type_I_cleaned.pdb -> output/receptor_files/7CWK_Collagen_type_I.pdbqt
# Found protein 'R-SPONDIN-1' with chains: ['A']
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/4BSO_R-SPONDIN-1_cleaned.pdb
# Conversion successful: output/receptor_files/4BSO_R-SPONDIN-1_cleaned.pdb -> output/receptor_files/4BSO_R-SPONDIN-1.pdbqt
# Removed 43 UNK/UNL residues from output/receptor_files/4BSO_R-SPONDIN-1.pdbqt
# Found protein 'HEPARIN-BINDING GROWTH FACTOR 1' with chains: ['A', 'B']
#
# Deduplicating chains with 80.0% similarity threshold...
# Chain A: Length=141, Unknown residues=0
# Chain B: Length=141, Unknown residues=0
#
# Comparing Chain A vs Chain B:
# 	- Similarity: 100.0%
# 	- Chains are 100.0% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain B: 0 unknown residues
# 	- Discarding Chain B (redundant)
#
# ============================================================
# Chains to keep: ['A']
# ============================================================
#
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/1RG8_Heparin-binding_growth_factor_1_cleaned.pdb
# Conversion successful: output/receptor_files/1RG8_Heparin-binding_growth_factor_1_cleaned.pdb -> output/receptor_files/1RG8_Heparin-binding_growth_factor_1.pdbqt
# Removed 13 UNK/UNL residues from output/receptor_files/1RG8_Heparin-binding_growth_factor_1.pdbqt
# Found protein 'GRANULOCYTE-MACROPHAGE COLONY-STIMULATING FACTOR' with chains: ['A', 'B']
#
# Deduplicating chains with 80.0% similarity threshold...
# Chain A: Length=120, Unknown residues=0
# Chain B: Length=120, Unknown residues=0
#
# Comparing Chain A vs Chain B:
# 	- Similarity: 100.0%
# 	- Chains are 100.0% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain B: 0 unknown residues
# 	- Discarding Chain B (redundant)
#
# ============================================================
# Chains to keep: ['A']
# ============================================================
#
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/1CSG_Granulocyte-macrophage_colony-stimulating_factor_cleaned.pdb
# Conversion successful: output/receptor_files/1CSG_Granulocyte-macrophage_colony-stimulating_factor_cleaned.pdb -> output/receptor_files/1CSG_Granulocyte-macrophage_colony-stimulating_factor.pdbqt
# Found protein 'TRANSFORMING GROWTH FACTOR-BETA 3' with chains: ['A']
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/1TGJ_TRANSFORMING_GROWTH_FACTOR-BETA_3_cleaned.pdb
# Conversion successful: output/receptor_files/1TGJ_TRANSFORMING_GROWTH_FACTOR-BETA_3_cleaned.pdb -> output/receptor_files/1TGJ_TRANSFORMING_GROWTH_FACTOR-BETA_3.pdbqt
# Removed 7 UNK/UNL residues from output/receptor_files/1TGJ_TRANSFORMING_GROWTH_FACTOR-BETA_3.pdbqt
# Found protein 'VASCULAR ENDOTHELIAL GROWTH FACTOR' with chains: ['A', 'B', 'C', 'D']
#
# Deduplicating chains with 80.0% similarity threshold...
# Chain A: Length=94, Unknown residues=0
# Chain B: Length=94, Unknown residues=0
# Chain C: Length=94, Unknown residues=0
# Chain D: Length=94, Unknown residues=0
#
# Comparing Chain A vs Chain B:
# 	- Similarity: 100.0%
# 	- Chains are 100.0% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain B: 0 unknown residues
# 	- Discarding Chain B (redundant)
#
# Comparing Chain A vs Chain C:
# 	- Similarity: 100.0%
# 	- Chains are 100.0% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain C: 0 unknown residues
# 	- Discarding Chain C (redundant)
#
# Comparing Chain A vs Chain D:
# 	- Similarity: 100.0%
# 	- Chains are 100.0% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain D: 0 unknown residues
# 	- Discarding Chain D (redundant)
#
# ============================================================
# Chains to keep: ['A']
# ============================================================
#
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/1VPF_VASCULAR_ENDOTHELIAL_GROWTH_FACTOR_cleaned.pdb
# Conversion successful: output/receptor_files/1VPF_VASCULAR_ENDOTHELIAL_GROWTH_FACTOR_cleaned.pdb -> output/receptor_files/1VPF_VASCULAR_ENDOTHELIAL_GROWTH_FACTOR.pdbqt
# Found protein 'TOLL-LIKE RECEPTOR 2, VARIABLE LYMPHOCYTE RECEPTOR B' with chains: ['A', 'B']
#
# Deduplicating chains with 80.0% similarity threshold...
# Chain A: Length=321, Unknown residues=0
# Chain B: Length=320, Unknown residues=0
#
# Comparing Chain A vs Chain B:
# 	- Similarity: 99.7%
# 	- Chains are 99.7% similar (≥80.0%)
# 	- Chain A: 0 unknown residues
# 	- Chain B: 0 unknown residues
# 	- Discarding Chain B (redundant)
#
# ============================================================
# Chains to keep: ['A']
# ============================================================
#
# Final chains to keep: ['A']
# Removed UNK/UNL residues from output/receptor_files/2Z80_Toll-like_receptor_2,_Variable_lymphocyte_receptor_B_cleaned.pdb
# Conversion successful: output/receptor_files/2Z80_Toll-like_receptor_2,_Variable_lymphocyte_receptor_B_cleaned.pdb -> output/receptor_files/2Z80_Toll-like_receptor_2,_Variable_lymphocyte_receptor_B.pdbqt

# %% [markdown]
# # 3. Run Molecular Docking

# %% [markdown]
# Copy and paste the following cell as needed...
# Depending on how many proteins you want to dock.

# %%
# Store docking results to export it as CSV file
docking_results = []

# %%
# Custom Library to run Autodock Vina Blind Docking
from docking_functions.BlindDocking import compute_bounding_box, calculate_receptor_center_of_mass, run_vina_blind_docking
from docking_functions.docking_utils import extract_pose_results
from IPython.display import clear_output

# Set directory structure
ligand_dir = os.path.join("output", "ligand_files")
receptor_dir = os.path.join("output", "receptor_files")
docking_dir = os.path.join("output", "docking")

# Create docking subdirectory
os.makedirs(docking_dir, exist_ok=True)

# 1. Iterate over each n-unit PHB PDBQT files
for num_units in range(1, 13):  # 1 to 12 units

    # 2. Get Ligand file
    phb_pdbqt = os.path.join(ligand_dir, f"phb_{num_units}_unit.pdbqt")

    # 3. Iterate over each protein (PDBQT files)
    for receptor_pdbqt in pdbqt_filenames:
        try:
            print(f"\n{'='*70}")
            print(f"Running docking for: {os.path.basename(receptor_pdbqt)} - {os.path.basename(phb_pdbqt)}")
            print(f"{'='*70}")

            # 4. Calculate center of protein
            grid_center = calculate_receptor_center_of_mass(receptor_pdbqt)
            # 5. Calculate size
            grid_size = compute_bounding_box(receptor_pdbqt)

            # 6. Extract PDB code for output naming
            pdb_code = os.path.basename(receptor_pdbqt).split("_")[0]
            output_subdir = f"phb_{num_units}_{pdb_code}"

            # 7. Run vina
            vina_results, error, vina_log_file = run_vina_blind_docking(
                # 1. Protein PDBQT filename
                receptor_pdbqt=receptor_pdbqt,
                # 2. Ligand PDBQT filename
                ligand_pdbqt=phb_pdbqt,
                # 3. Align Protein and Ligand inside Grid size
                align_ligand=True,
                # 4. Docking Output Directory
                output_folder=docking_dir,
                # 5. Center of protein
                center=grid_center,
                # 6. Box grid size
                size=grid_size,
                # 7. Is energy minimized ligand?
                ligand_minimized=True,
                # 8. Computational power (Minimum = 8; Standard = 32)
                exhaustiveness=32,
                # 9. Number of conformational ligand poses
                num_modes=8,
                # 10. Number of CPUs available
                cpu=-1,
                # 11. Set seed for reproducible results
                seed=1234,
                # 12. Save all conformational ligand poses
                save_poses="all",
                # 13. Output filenames
                output_filename=output_subdir
            )

            if error:
                print(f"Error: {error}")
            else:
                print(f"Best affinity: {vina_results['best_affinity']:.2f} kcal/mol")
                print(f"Poses saved: {len(vina_results['pose_files'])}")
                
                # Extract all poses results
                result_dicts = extract_pose_results(
                    vina_results,
                    receptor_pdbqt,
                    phb_pdbqt,
                    output_subdir,
                    poses='all'
                )

                if result_dicts:
                    # Handle both single dict and list of dicts
                    if isinstance(result_dicts, list):
                        docking_results.extend(result_dicts)
                        print(f"\t- Extracted {len(result_dicts)} poses for {os.path.basename(receptor_pdbqt)}")
                    else:
                        docking_results.append(result_dicts)
                        print(f"\t- Completed docking for {os.path.basename(receptor_pdbqt)}")
                else:
                    print(f"\t- No results for {os.path.basename(receptor_pdbqt)}")        
        except Exception as e:
            print(f"Error: {e}")

        clear_output(wait=True) # Clears the current output before the next iteration

print(f"\n{'='*70}")
print(f"\t- Docking complete!")
print(f"Total results collected: {len(docking_results)}")
print(f"{'='*70}")
# Out:
# ======================================================================
# 	- Docking complete!
# Total results collected: 704
# ======================================================================

# %%
import pandas as pd
from docking_functions.docking_utils import export_docking_results

# DataFrame filename
df_filename = "output/docking_results_summary.csv"

# Create DataFrame from all results
if docking_results:
    df_results = pd.DataFrame(docking_results)
    
    print("\n" + "="*50)
    print("All Docking Results:")
    print("="*50)
    print(df_results)
    
    # Export results using the export function
    export_docking_results(df_results, 
                           df_filename,
                           include_timestamp=False)

    # Optional: Sort by affinity
    df_sorted = df_results.sort_values('affinity_kcal_mol')
    print("\n" + "="*50)
    print("Results sorted by affinity (best to worst):")
    print("="*50)
    print(df_sorted[['protein_file', 'ligand_file', 'affinity_kcal_mol']])

else:
    print("No docking results were collected.")
# Out:
# ==================================================
# All Docking Results:
# ==================================================
#                                           protein_file        ligand_file  \
# 0                                 6EC0_Keratin_1.pdbqt   phb_1_unit.pdbqt
# 1                                 6EC0_Keratin_1.pdbqt   phb_1_unit.pdbqt
# 2                                 6EC0_Keratin_1.pdbqt   phb_1_unit.pdbqt
# 3                                 6EC0_Keratin_1.pdbqt   phb_1_unit.pdbqt
# 4                                 6EC0_Keratin_1.pdbqt   phb_1_unit.pdbqt
# ..                                                 ...                ...
# 699  2Z80_Toll-like_receptor_2,_Variable_lymphocyte...  phb_12_unit.pdbqt
# 700  2Z80_Toll-like_receptor_2,_Variable_lymphocyte...  phb_12_unit.pdbqt
# 701  2Z80_Toll-like_receptor_2,_Variable_lymphocyte...  phb_12_unit.pdbqt
# 702  2Z80_Toll-like_receptor_2,_Variable_lymphocyte...  phb_12_unit.pdbqt
# 703  2Z80_Toll-like_receptor_2,_Variable_lymphocyte...  phb_12_unit.pdbqt
#
#      output_name  pose_number  affinity_kcal_mol  rmsd_lb  rmsd_ub  \
# 0     phb_1_6EC0            1             -2.801    0.000    0.000
# 1     phb_1_6EC0            2             -2.584   11.067   11.538
# 2     phb_1_6EC0            3             -2.544   42.493   42.855
# 3     phb_1_6EC0            4             -2.535   47.676   48.101
# 4     phb_1_6EC0            5             -2.528   71.831   72.263
# ..           ...          ...                ...      ...      ...
# 699  phb_12_2Z80            4             -5.257   18.896   23.740
# 700  phb_12_2Z80            5             -5.247   11.811   18.724
# 701  phb_12_2Z80            6             -5.213   19.419   23.285
# 702  phb_12_2Z80            7             -5.188    2.520    8.400
# 703  phb_12_2Z80            8             -5.184    3.708   10.149
#
#      grid_center_x  grid_center_y  grid_center_z  grid_size_x  grid_size_y  \
# 0        23.579323     -33.157310       3.113046    83.548004    55.468998
# 1        23.579323     -33.157310       3.113046    83.548004    55.468998
# 2        23.579323     -33.157310       3.113046    83.548004    55.468998
# 3        23.579323     -33.157310       3.113046    83.548004    55.468998
# 4        23.579323     -33.157310       3.113046    83.548004    55.468998
# ..             ...            ...            ...          ...          ...
# 699      -0.322032     -11.993623     -22.652592    53.501999    73.524002
# 700      -0.322032     -11.993623     -22.652592    53.501999    73.524002
# 701      -0.322032     -11.993623     -22.652592    53.501999    73.524002
# 702      -0.322032     -11.993623     -22.652592    53.501999    73.524002
# 703      -0.322032     -11.993623     -22.652592    53.501999    73.524002
#
#      grid_size_z  elapsed_time_seconds minimization_before minimization_after  \
# 0     138.848999              1.809033                None               None
# 1     138.848999              1.809033                None               None
# 2     138.848999              1.809033                None               None
# 3     138.848999              1.809033                None               None
# 4     138.848999              1.809033                None               None
# ..           ...                   ...                 ...                ...
# 699    47.835999           1066.555438                None               None
# 700    47.835999           1066.555438                None               None
# 701    47.835999           1066.555438                None               None
# 702    47.835999           1066.555438                None               None
# 703    47.835999           1066.555438                None               None
#
#                                               zip_file  \
# 0    output/docking/phb_1_6EC0/phb_1_6EC0_all_poses...
# 1    output/docking/phb_1_6EC0/phb_1_6EC0_all_poses...
# 2    output/docking/phb_1_6EC0/phb_1_6EC0_all_poses...
# 3    output/docking/phb_1_6EC0/phb_1_6EC0_all_poses...
# 4    output/docking/phb_1_6EC0/phb_1_6EC0_all_poses...
# ..                                                 ...
# 699  output/docking/phb_12_2Z80/phb_12_2Z80_all_pos...
# 700  output/docking/phb_12_2Z80/phb_12_2Z80_all_pos...
# 701  output/docking/phb_12_2Z80/phb_12_2Z80_all_pos...
# 702  output/docking/phb_12_2Z80/phb_12_2Z80_all_pos...
# 703  output/docking/phb_12_2Z80/phb_12_2Z80_all_pos...
#
#                   output_folder
# 0     output/docking/phb_1_6EC0
# 1     output/docking/phb_1_6EC0
# 2     output/docking/phb_1_6EC0
# 3     output/docking/phb_1_6EC0
# 4     output/docking/phb_1_6EC0
# ..                          ...
# 699  output/docking/phb_12_2Z80
# 700  output/docking/phb_12_2Z80
# 701  output/docking/phb_12_2Z80
# 702  output/docking/phb_12_2Z80
# 703  output/docking/phb_12_2Z80
#
# [704 rows x 18 columns]
# Results exported to: output/docking_results_summary.csv
#
# ==================================================
# Results sorted by affinity (best to worst):
# ==================================================
#                                    protein_file       ligand_file  \
# 512  1RG8_Heparin-binding_growth_factor_1.pdbqt  phb_9_unit.pdbqt
# 513  1RG8_Heparin-binding_growth_factor_1.pdbqt  phb_9_unit.pdbqt
# 514  1RG8_Heparin-binding_growth_factor_1.pdbqt  phb_9_unit.pdbqt
# 515  1RG8_Heparin-binding_growth_factor_1.pdbqt  phb_9_unit.pdbqt
# 516  1RG8_Heparin-binding_growth_factor_1.pdbqt  phb_9_unit.pdbqt
# ..                                          ...               ...
# 11                   7CWK_Collagen_type_I.pdbqt  phb_1_unit.pdbqt
# 12                   7CWK_Collagen_type_I.pdbqt  phb_1_unit.pdbqt
# 13                   7CWK_Collagen_type_I.pdbqt  phb_1_unit.pdbqt
# 14                   7CWK_Collagen_type_I.pdbqt  phb_1_unit.pdbqt
# 15                   7CWK_Collagen_type_I.pdbqt  phb_1_unit.pdbqt
#
#      affinity_kcal_mol
# 512             -7.803
# 513             -7.585
# 514             -7.556
# 515             -7.527
# 516             -7.527
# ..                 ...
# 11              -2.149
# 12              -2.145
# 13              -2.119
# 14              -2.057
# 15              -2.031
#
# [704 rows x 3 columns]

# %% [markdown]
# ## END
